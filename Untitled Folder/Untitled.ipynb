# %%
# !pip install pandas --upgrade --quiet
# Out:
# Unable to create process using 'C:\Users\Rishabh Sharma\anaconda3\python.exe "C:\Users\Rishabh Sharma\anaconda3\Scripts\pip-script.py" install pandas --upgrade --quiet'

# %%
import pandas as pd

# %%
from urllib.request import urlretrieve

# %%
italy_covid_url = 'https://gist.githubusercontent.com/aakashns/f6a004fa20c84fec53262f9a8bfee775/raw/f309558b1cf5103424cef58e2ecb8704dcd4d74c/italy-covid-daywise.csv'

urlretrieve(italy_covid_url, 'italy-covid-daywise.csv')
# Out:
# ('italy-covid-daywise.csv', <http.client.HTTPMessage at 0x2b3ea16f6d0>)

# %%
covid_df = pd.read_csv('italy-covid-daywise.csv')

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
covid_df['date']=pd.to_datetime(covid_df.date)

# %%
type(covid_df.date)
# Out:
# pandas.core.series.Series

# %%
covid_df['month']=pd.DatetimeIndex(covid_df.date).month
covid_df['year']=pd.DatetimeIndex(covid_df.date).year
covid_df['day']=pd.DatetimeIndex(covid_df.date).day
covid_df['weekday']=pd.DatetimeIndex(covid_df.date).weekday

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  month  year  day  weekday
# 0   2019-12-31        0.0         0.0        NaN     12  2019   31        1
# 1   2020-01-01        0.0         0.0        NaN      1  2020    1        2
# 2   2020-01-02        0.0         0.0        NaN      1  2020    2        3
# 3   2020-01-03        0.0         0.0        NaN      1  2020    3        4
# 4   2020-01-04        0.0         0.0        NaN      1  2020    4        5
# ..         ...        ...         ...        ...    ...   ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0      8  2020   30        6
# 244 2020-08-31     1365.0         4.0    42583.0      8  2020   31        0
# 245 2020-09-01      996.0         6.0    54395.0      9  2020    1        1
# 246 2020-09-02      975.0         8.0        NaN      9  2020    2        2
# 247 2020-09-03     1326.0         6.0        NaN      9  2020    3        3
#
# [248 rows x 8 columns]

# %%
covid_df_may= covid_df[covid_df.month==5]

# %%
covid_df_may
# Out:
#           date  new_cases  new_deaths  new_tests  month  year  day  weekday
# 122 2020-05-01     1872.0       285.0    43732.0      5  2020    1        4
# 123 2020-05-02     1965.0       269.0    31231.0      5  2020    2        5
# 124 2020-05-03     1900.0       474.0    27047.0      5  2020    3        6
# 125 2020-05-04     1389.0       174.0    22999.0      5  2020    4        0
# 126 2020-05-05     1221.0       195.0    32211.0      5  2020    5        1
# 127 2020-05-06     1075.0       236.0    37771.0      5  2020    6        2
# 128 2020-05-07     1444.0       369.0    13665.0      5  2020    7        3
# 129 2020-05-08     1401.0       274.0    45428.0      5  2020    8        4
# 130 2020-05-09     1327.0       243.0    36091.0      5  2020    9        5
# 131 2020-05-10     1083.0       194.0    31384.0      5  2020   10        6
# 132 2020-05-11      802.0       165.0    25823.0      5  2020   11        0
# 133 2020-05-12      744.0       179.0    39620.0      5  2020   12        1
# 134 2020-05-13     1402.0       172.0    37049.0      5  2020   13        2
# 135 2020-05-14      888.0       195.0    41131.0      5  2020   14        3
# 136 2020-05-15      992.0       262.0    39027.0      5  2020   15        4
# 137 2020-05-16      789.0       242.0    40657.0      5  2020   16        5
# 138 2020-05-17      875.0       153.0    33505.0      5  2020   17        6
# 139 2020-05-18      675.0       145.0    26101.0      5  2020   18        0
# 140 2020-05-19      451.0        99.0    40226.0      5  2020   19        1
# 141 2020-05-20      813.0       162.0    38617.0      5  2020   20        2
# 142 2020-05-21      665.0       161.0    40644.0      5  2020   21        3
# 143 2020-05-22      642.0       156.0    42987.0      5  2020   22        4
# 144 2020-05-23      652.0       130.0    42579.0      5  2020   23        5
# 145 2020-05-24      669.0       119.0    34206.0      5  2020   24        6
# 146 2020-05-25      531.0        50.0    20676.0      5  2020   25        0
# 147 2020-05-26      300.0        92.0    33944.0      5  2020   26        1
# 148 2020-05-27      397.0        78.0    37299.0      5  2020   27        2
# 149 2020-05-28      584.0       117.0    39838.0      5  2020   28        3
# 150 2020-05-29      593.0        70.0    38233.0      5  2020   29        4
# 151 2020-05-30      516.0        87.0    36051.0      5  2020   30        5
# 152 2020-05-31      416.0       111.0    28948.0      5  2020   31        6

# %%
covid_df_may_metrics=covid_df_may[['new_cases','new_deaths','new_tests']]

# %%
covid_df_may_metrics
# Out:
#      new_cases  new_deaths  new_tests
# 122     1872.0       285.0    43732.0
# 123     1965.0       269.0    31231.0
# 124     1900.0       474.0    27047.0
# 125     1389.0       174.0    22999.0
# 126     1221.0       195.0    32211.0
# 127     1075.0       236.0    37771.0
# 128     1444.0       369.0    13665.0
# 129     1401.0       274.0    45428.0
# 130     1327.0       243.0    36091.0
# 131     1083.0       194.0    31384.0
# 132      802.0       165.0    25823.0
# 133      744.0       179.0    39620.0
# 134     1402.0       172.0    37049.0
# 135      888.0       195.0    41131.0
# 136      992.0       262.0    39027.0
# 137      789.0       242.0    40657.0
# 138      875.0       153.0    33505.0
# 139      675.0       145.0    26101.0
# 140      451.0        99.0    40226.0
# 141      813.0       162.0    38617.0
# 142      665.0       161.0    40644.0
# 143      642.0       156.0    42987.0
# 144      652.0       130.0    42579.0
# 145      669.0       119.0    34206.0
# 146      531.0        50.0    20676.0
# 147      300.0        92.0    33944.0
# 148      397.0        78.0    37299.0
# 149      584.0       117.0    39838.0
# 150      593.0        70.0    38233.0
# 151      516.0        87.0    36051.0
# 152      416.0       111.0    28948.0

# %%
covid_df_may_total=covid_df_may_metrics.sum()

# %%
covid_df_may_total
# Out:
# new_cases       29073.0
# new_deaths       5658.0
# new_tests     1078720.0
# dtype: float64

# %%
covid_df_may.mean()
# Out:
# <ipython-input-17-be359aea5660>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   covid_df_may.mean()
# new_cases       937.838710
# new_deaths      182.516129
# new_tests     34797.419355
# month             5.000000
# year           2020.000000
# day              16.000000
# weekday           3.193548
# dtype: float64

# %%
covid_df.new_cases[covid_df.weekday==6].mean()
# Out:
# 1247.2571428571428

# %%
covid_month_df=covid_df.groupby('month').sum()

# %% [raw]
# covid_month_df

# %%
covid_month_df
# Out:
#        new_cases  new_deaths  new_tests   year  day  weekday
# month
# 1            3.0         0.0        0.0  62620  496       93
# 2          885.0        21.0        0.0  58580  435       89
# 3       100851.0     11570.0        0.0  62620  496       91
# 4       101852.0     16091.0   419591.0  60600  465       89
# 5        29073.0      5658.0  1078720.0  62620  496       99
# 6         7772.0      1404.0   830354.0  60600  465       85
# 7         6722.0       388.0   797692.0  62620  496       93
# 8        21060.0       345.0  1098704.0  62620  496       95
# 9         3297.0        20.0    54395.0   6060    6        6
# 12           0.0         0.0        0.0   2019   31        1

# %%
covid_month_mean=covid_df.groupby('month')[['new_cases','new_deaths','new_tests']].mean()

# %%
covid_month_mean
# Out:
#          new_cases  new_deaths     new_tests
# month
# 1         0.096774    0.000000           NaN
# 2        30.517241    0.724138           NaN
# 3      3253.258065  373.225806           NaN
# 4      3395.066667  536.366667  38144.636364
# 5       937.838710  182.516129  34797.419355
# 6       259.066667   46.800000  27678.466667
# 7       216.838710   12.516129  25732.000000
# 8       679.354839   11.129032  35442.064516
# 9      1099.000000    6.666667  54395.000000
# 12        0.000000    0.000000           NaN

# %%
covid_df['total_cases'] = covid_df.new_cases.cumsum()

# %%
covid_df['total_deaths'] = covid_df.new_deaths.cumsum()

# %%
covid_df['total_tests'] = covid_df.new_tests.cumsum()

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  month  year  day  weekday  \
# 0   2019-12-31        0.0         0.0        NaN     12  2019   31        1
# 1   2020-01-01        0.0         0.0        NaN      1  2020    1        2
# 2   2020-01-02        0.0         0.0        NaN      1  2020    2        3
# 3   2020-01-03        0.0         0.0        NaN      1  2020    3        4
# 4   2020-01-04        0.0         0.0        NaN      1  2020    4        5
# ..         ...        ...         ...        ...    ...   ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0      8  2020   30        6
# 244 2020-08-31     1365.0         4.0    42583.0      8  2020   31        0
# 245 2020-09-01      996.0         6.0    54395.0      9  2020    1        1
# 246 2020-09-02      975.0         8.0        NaN      9  2020    2        2
# 247 2020-09-03     1326.0         6.0        NaN      9  2020    3        3
#
#      total_cases  total_deaths  total_tests
# 0            0.0           0.0          NaN
# 1            0.0           0.0          NaN
# 2            0.0           0.0          NaN
# 3            0.0           0.0          NaN
# 4            0.0           0.0          NaN
# ..           ...           ...          ...
# 243     266853.0       35473.0    4182478.0
# 244     268218.0       35477.0    4225061.0
# 245     269214.0       35483.0    4279456.0
# 246     270189.0       35491.0          NaN
# 247     271515.0       35497.0          NaN
#
# [248 rows x 11 columns]

# %%
urlretrieve('https://gist.githubusercontent.com/aakashns/8684589ef4f266116cdce023377fc9c8/raw/99ce3826b2a9d1e6d0bde7e9e559fc8b6e9ac88b/locations.csv', 
            'locations.csv')
# Out:
# ('locations.csv', <http.client.HTTPMessage at 0x2b3ea2a5dc0>)

# %%
location_df=pd.read_csv('locations.csv')

# %%
location_df
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# 4                           NaN        5819.495
# ..                          ...             ...
# 207                       0.700        1479.147
# 208                       2.000        3689.251
# 209                       1.700        1899.775
# 210                       2.705       15469.207
# 211                         NaN             NaN
#
# [212 rows x 6 columns]

# %%
covid_df['location']='Italy'

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  month  year  day  weekday  \
# 0   2019-12-31        0.0         0.0        NaN     12  2019   31        1
# 1   2020-01-01        0.0         0.0        NaN      1  2020    1        2
# 2   2020-01-02        0.0         0.0        NaN      1  2020    2        3
# 3   2020-01-03        0.0         0.0        NaN      1  2020    3        4
# 4   2020-01-04        0.0         0.0        NaN      1  2020    4        5
# ..         ...        ...         ...        ...    ...   ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0      8  2020   30        6
# 244 2020-08-31     1365.0         4.0    42583.0      8  2020   31        0
# 245 2020-09-01      996.0         6.0    54395.0      9  2020    1        1
# 246 2020-09-02      975.0         8.0        NaN      9  2020    2        2
# 247 2020-09-03     1326.0         6.0        NaN      9  2020    3        3
#
#      total_cases  total_deaths  total_tests location
# 0            0.0           0.0          NaN    Italy
# 1            0.0           0.0          NaN    Italy
# 2            0.0           0.0          NaN    Italy
# 3            0.0           0.0          NaN    Italy
# 4            0.0           0.0          NaN    Italy
# ..           ...           ...          ...      ...
# 243     266853.0       35473.0    4182478.0    Italy
# 244     268218.0       35477.0    4225061.0    Italy
# 245     269214.0       35483.0    4279456.0    Italy
# 246     270189.0       35491.0          NaN    Italy
# 247     271515.0       35497.0          NaN    Italy
#
# [248 rows x 12 columns]

# %%
merged_df = covid_df.merge(location_df, on="location")

# %%
merged_df
# Out:
#           date  new_cases  new_deaths  new_tests  month  year  day  weekday  \
# 0   2019-12-31        0.0         0.0        NaN     12  2019   31        1
# 1   2020-01-01        0.0         0.0        NaN      1  2020    1        2
# 2   2020-01-02        0.0         0.0        NaN      1  2020    2        3
# 3   2020-01-03        0.0         0.0        NaN      1  2020    3        4
# 4   2020-01-04        0.0         0.0        NaN      1  2020    4        5
# ..         ...        ...         ...        ...    ...   ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0      8  2020   30        6
# 244 2020-08-31     1365.0         4.0    42583.0      8  2020   31        0
# 245 2020-09-01      996.0         6.0    54395.0      9  2020    1        1
# 246 2020-09-02      975.0         8.0        NaN      9  2020    2        2
# 247 2020-09-03     1326.0         6.0        NaN      9  2020    3        3
#
#      total_cases  total_deaths  total_tests location continent  population  \
# 0            0.0           0.0          NaN    Italy    Europe  60461828.0
# 1            0.0           0.0          NaN    Italy    Europe  60461828.0
# 2            0.0           0.0          NaN    Italy    Europe  60461828.0
# 3            0.0           0.0          NaN    Italy    Europe  60461828.0
# 4            0.0           0.0          NaN    Italy    Europe  60461828.0
# ..           ...           ...          ...      ...       ...         ...
# 243     266853.0       35473.0    4182478.0    Italy    Europe  60461828.0
# 244     268218.0       35477.0    4225061.0    Italy    Europe  60461828.0
# 245     269214.0       35483.0    4279456.0    Italy    Europe  60461828.0
# 246     270189.0       35491.0          NaN    Italy    Europe  60461828.0
# 247     271515.0       35497.0          NaN    Italy    Europe  60461828.0
#
#      life_expectancy  hospital_beds_per_thousand  gdp_per_capita
# 0              83.51                        3.18       35220.084
# 1              83.51                        3.18       35220.084
# 2              83.51                        3.18       35220.084
# 3              83.51                        3.18       35220.084
# 4              83.51                        3.18       35220.084
# ..               ...                         ...             ...
# 243            83.51                        3.18       35220.084
# 244            83.51                        3.18       35220.084
# 245            83.51                        3.18       35220.084
# 246            83.51                        3.18       35220.084
# 247            83.51                        3.18       35220.084
#
# [248 rows x 17 columns]

# %%
merged_df['cases_per_million'] = merged_df.total_cases * 1e6 / merged_df.population

# %%
merged_df['deaths_per_million'] = merged_df.total_deaths * 1e6 / merged_df.population

# %%
merged_df['tests_per_million'] = merged_df.total_tests * 1e6 / merged_df.population

# %%
merged_df
# Out:
#           date  new_cases  new_deaths  new_tests  month  year  day  weekday  \
# 0   2019-12-31        0.0         0.0        NaN     12  2019   31        1
# 1   2020-01-01        0.0         0.0        NaN      1  2020    1        2
# 2   2020-01-02        0.0         0.0        NaN      1  2020    2        3
# 3   2020-01-03        0.0         0.0        NaN      1  2020    3        4
# 4   2020-01-04        0.0         0.0        NaN      1  2020    4        5
# ..         ...        ...         ...        ...    ...   ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0      8  2020   30        6
# 244 2020-08-31     1365.0         4.0    42583.0      8  2020   31        0
# 245 2020-09-01      996.0         6.0    54395.0      9  2020    1        1
# 246 2020-09-02      975.0         8.0        NaN      9  2020    2        2
# 247 2020-09-03     1326.0         6.0        NaN      9  2020    3        3
#
#      total_cases  total_deaths  total_tests location continent  population  \
# 0            0.0           0.0          NaN    Italy    Europe  60461828.0
# 1            0.0           0.0          NaN    Italy    Europe  60461828.0
# 2            0.0           0.0          NaN    Italy    Europe  60461828.0
# 3            0.0           0.0          NaN    Italy    Europe  60461828.0
# 4            0.0           0.0          NaN    Italy    Europe  60461828.0
# ..           ...           ...          ...      ...       ...         ...
# 243     266853.0       35473.0    4182478.0    Italy    Europe  60461828.0
# 244     268218.0       35477.0    4225061.0    Italy    Europe  60461828.0
# 245     269214.0       35483.0    4279456.0    Italy    Europe  60461828.0
# 246     270189.0       35491.0          NaN    Italy    Europe  60461828.0
# 247     271515.0       35497.0          NaN    Italy    Europe  60461828.0
#
#      life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# 0              83.51                        3.18       35220.084
# 1              83.51                        3.18       35220.084
# 2              83.51                        3.18       35220.084
# 3              83.51                        3.18       35220.084
# 4              83.51                        3.18       35220.084
# ..               ...                         ...             ...
# 243            83.51                        3.18       35220.084
# 244            83.51                        3.18       35220.084
# 245            83.51                        3.18       35220.084
# 246            83.51                        3.18       35220.084
# 247            83.51                        3.18       35220.084
#
#      cases_per_million  deaths_per_million  tests_per_million
# 0             0.000000            0.000000                NaN
# 1             0.000000            0.000000                NaN
# 2             0.000000            0.000000                NaN
# 3             0.000000            0.000000                NaN
# 4             0.000000            0.000000                NaN
# ..                 ...                 ...                ...
# 243        4413.578101          586.700753       69175.513516
# 244        4436.154329          586.766910       69879.809125
# 245        4452.627532          586.866146       70779.467667
# 246        4468.753409          586.998461                NaN
# 247        4490.684602          587.097697                NaN
#
# [248 rows x 20 columns]

# %%
result_df=merged_df[['date',
                    'new_cases',
                    'total_cases',
                    'new_deaths',
                    'total_deaths',
                    'new_tests',
                    'total_tests',
                    'cases_per_million', 
                    'deaths_per_million', 
                    'tests_per_million']]

# %%
result_df
# Out:
#           date  new_cases  total_cases  new_deaths  total_deaths  new_tests  \
# 0   2019-12-31        0.0          0.0         0.0           0.0        NaN
# 1   2020-01-01        0.0          0.0         0.0           0.0        NaN
# 2   2020-01-02        0.0          0.0         0.0           0.0        NaN
# 3   2020-01-03        0.0          0.0         0.0           0.0        NaN
# 4   2020-01-04        0.0          0.0         0.0           0.0        NaN
# ..         ...        ...          ...         ...           ...        ...
# 243 2020-08-30     1444.0     266853.0         1.0       35473.0    53541.0
# 244 2020-08-31     1365.0     268218.0         4.0       35477.0    42583.0
# 245 2020-09-01      996.0     269214.0         6.0       35483.0    54395.0
# 246 2020-09-02      975.0     270189.0         8.0       35491.0        NaN
# 247 2020-09-03     1326.0     271515.0         6.0       35497.0        NaN
#
#      total_tests  cases_per_million  deaths_per_million  tests_per_million
# 0            NaN           0.000000            0.000000                NaN
# 1            NaN           0.000000            0.000000                NaN
# 2            NaN           0.000000            0.000000                NaN
# 3            NaN           0.000000            0.000000                NaN
# 4            NaN           0.000000            0.000000                NaN
# ..           ...                ...                 ...                ...
# 243    4182478.0        4413.578101          586.700753       69175.513516
# 244    4225061.0        4436.154329          586.766910       69879.809125
# 245    4279456.0        4452.627532          586.866146       70779.467667
# 246          NaN        4468.753409          586.998461                NaN
# 247          NaN        4490.684602          587.097697                NaN
#
# [248 rows x 10 columns]

# %%
result_df.to_csv('results.csv', index='date')

# %%
result_df.new_cases.plot();
result_df.new_deaths.plot();

# %%
result_df.total_cases.plot();

# %%
result_df.new_tests.plot();

# %%
result_df.new_cases.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
covid_month_df.new_cases.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='month'>

# %%
# !pip install matplotlib seaborn --upgrade --quiet
# Out:
# Unable to create process using 'C:\Users\Rishabh Sharma\anaconda3\python.exe "C:\Users\Rishabh Sharma\anaconda3\Scripts\pip-script.py" install matplotlib seaborn --upgrade --quiet'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
import numpy as np

# %%
plt.plot(yield_apples)

# %%
years=range(2010,2016)
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(years,yield_apples)
plt.xlabel('Year')
plt.ylabel('Yield');

# %%
years=range(2000,2012)
sns.set_style('darkgrid')
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
plt.plot(years,apples,'s-b')
plt.plot(years,oranges,'o--r')
plt.xlabel("Year")
plt.ylabel('yield')
plt.title('Crop yields in kanto')
plt.legend(['Apples','Oranges']);

# %%
flowers_df=sns.load_dataset('iris')

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.plot(flowers_df.sepal_length,flowers_df.sepal_width)

# %%
sns.scatterplot(x=flowers_df.sepal_length, y = flowers_df.sepal_width , hue = flowers_df.species)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.title("dstribution of sepal wdith")
plt.hist(flowers_df.sepal_width , bins=np.arange(2,5,0.25));

# %%
setosa_df=flowers_df[flowers_df.species=='setosa']
versicolor_df=flowers_df[flowers_df.species=='versicolor']
virginica_df=flowers_df[flowers_df.species=='virginica']

# %%
plt.title('Distribution of Sepal Width')

plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins=np.arange(2, 5, 0.25), 
         stacked=True);

plt.legend(['Setosa', 'Versicolor', 'Virginica']);
